# %% [markdown]
# **1. List**

# %%
numbers= [4,8,15,16,23]
print(numbers)
# Out:
# [4, 8, 15, 16, 23]

# %%
numbers.append(42)
numbers.insert(1,5)
numbers.insert(3,22)
print(numbers)
# Out:
# [4, 5, 8, 22, 15, 16, 23, 42]

# %%
for i in numbers:
  print(i)
# Out:
# 4
# 5
# 8
# 22
# 15
# 16
# 23
# 42

# %% [markdown]
# **2.Dictionary**

# %%
citizen={"name":"John","age":25,"address":"New York"}

# %%
citizen["phone"]="1234567890"
print(citizen)
# Out:
# {'name': 'John', 'age': 25, 'address': 'New York', 'phone': '1234567890'}

# %% [markdown]
# **3.Set**

# %%
set1={1,2,3,4,5}

# %%
set1.add(6)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.remove(3)
print(set1)
# Out:
# {1, 2, 4, 5, 6}

# %% [markdown]
# **4.Tuple**

# %%
a=(1,2,3,4)

# %%
print(len(a))
# Out:
# 4
